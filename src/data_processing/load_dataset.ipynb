# %%
import pandas as pd
from pathlib import Path

dir = Path(".")
df1 = pd.read_csv(dir / "songs_with_attributes_and_lyrics.csv")

df_condensed = df1.iloc[::12]
df_condensed.to_csv(dir / "songs_condensed.csv", index=False)
# Out:
#                         id                                               name  \
# 0   0Prct5TDjAnEgIqbxcldY9                                                  !
# 1   0wtpkz93wATDkUExJVuXEl  " La Traviata " : Amami Alfredo (Act II) - Dig...
# 2   7ygnMprPnDekUSeduRDhDt                                   "A Lovely Night"
# 3   4jX5YH4N3E32pmLz1AlAuT                     "B" Movie Box Car Blues - Live
# 4   0ZEgWDVmwVBb3LTzkbq4WT                                  "C" Is for Cookie
# ..                     ...                                                ...
# 95  5tpqiMJzVD9REO6DIf38VA                                (Feels Like) Heaven
# 96  0bY2jjd3PDpjFO6bzTDbUI         (For You) I'd Chase a Rainbow - Remastered
# 97  6I14WQ1CknW7hiCfNiJybq       (Get Your Kicks On) Route 66 - 2006 Remaster
# 98  4ncVYIs3UFvitjvc8RIPkM  (Ghost) Riders In the Sky - Digitally Remaster...
# 99  4ZJyczR2ngPILwH42asnwf                    (Goin' All Out) Nothin' To Lose
#
#                  album_name                                 artists  \
# 0                UNDEN!ABLE                            ['HELLYEAH']
# 1                       NaN                            Maria Callas
# 2                       NaN                             Laura Osnes
# 3   Briefcase Full of Blues  ['The Blues Brothers', 'Joe Gastwirt']
# 4                       NaN                       Little Apple Band
# ..                      ...                                     ...
# 95                      NaN                     ['Various Artists']
# 96                      NaN                            ['kalapana']
# 97                      NaN                            Dr. Feelgood
# 98             Ghost Riders                         ['The Outlaws']
# 99                       IV                        ['Cypress Hill']
#
#     danceability  energy  key  loudness   mode  speechiness  acousticness  \
# 0          0.415   0.605    7   -11.157      1       0.0575       0.00116
# 1          0.364   0.275    F   -11.832  Major       0.0430       0.99300
# 2          0.428   0.503    7    -6.950      1       0.2250       0.83000
# 3          0.606   0.819    9    -8.281      1       0.0696       0.56400
# 4          0.553   0.812   D#    -5.542  Major       0.0558       0.13200
# ..           ...     ...  ...       ...    ...          ...           ...
# 95         0.539   0.871  0.0    -8.466    0.0       0.0379       0.07720
# 96         0.531   0.362    9   -12.243      0       0.0282       0.26700
# 97         0.524   0.900    9    -7.619      1       0.0441       0.00587
# 98         0.228   0.896    9    -7.241      0       0.1300       0.01320
# 99         0.541   0.779    6   -12.458      1       0.2400       0.00112
#
#     instrumentalness  liveness  valence    tempo  duration_ms  \
# 0           0.838000    0.4710   0.1930  100.059      79500.0
# 1           0.028400    0.2930   0.0394   86.096     131933.0
# 2           0.000000    0.2470   0.6900  202.819     151467.0
# 3           0.004040    0.9590   0.5040   93.307     244400.0
# 4           0.000010    0.0794   0.8710  118.368      84306.0
# ..               ...       ...      ...      ...          ...
# 95          0.007850    0.1180   0.7950  116.840     209680.0
# 96          0.000001    0.1320   0.2520  125.403     178333.0
# 97          0.000642    0.1950   0.7960  168.855     203213.0
# 98          0.027300    0.7950   0.1460  128.433     351400.0
# 99          0.017000    0.0609   0.9160   98.962     232200.0
#
#                                                lyrics
# 0   He said he came from Jamaica,\n he owned a cou...
# 1   Ch'ei qui non mi sorprenda\n Lascia che m'allo...
# 2   A lovely night, a lovely night\n A finer night...
# 3   Caught a ride into South Dakota\n With two gir...
# 4   C is for cookie, that's good enough for me\n C...
# ..                                                ...
# 95  Heaven is closer now today\n The sound is in m...
# 96  Once I thought she really needed me\n All thos...
# 97  If you ever plan to motor west\n Travel my way...
# 98  An old cowboy went ridin' out one dark and win...
# 99  I got nothin to lose, I'm goin all out\n The d...
#
# [100 rows x 17 columns]
